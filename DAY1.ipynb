# %% [markdown]
# # Day 1 — Python & Git Foundations: Setup, Environment & Syntax
#
# ## Learning Objectives
# - Understand Python's execution model.
# - Set up VS Code and Python 3.x.
# - Write and run Python scripts in the terminal.
# - Initialize local Git version control (`git init`, `git config`).

# %% [markdown]
# ## 1. Syntax Basics & Output

# %%
# Day 1: Python Basic Output and Comments

print("==========================================")
print("Welcome to Python + Git Zero-to-Hero!")
print("==========================================")

# Multi-line docstring demonstration
"""
This is a multi-line docstring.
It is often used for documenting modules and functions.
"""

print("Executing line 1...")
print("Executing line 2...")
print("Python environment setup successful!")

# %% [markdown]
# ## 2. Code Practice & Debugging

# %%
# Practice 1: Banner Output
print("************************************")
print("Developer: Alex | IDE: VS Code | OS: Windows")
print("************************************")

# Debugging Drill: Fix syntax errors
# Corrected syntax:
print("Starting Python Program")
print("Learning Python Syntax")
print("Line 3 complete")

# %% [markdown]
# ## 3. Git Practice Commands
# ```bash
# git config --global user.name "Your Name"
# git config --global user.email "your.email@example.com"
# git init
# git status
# ```
