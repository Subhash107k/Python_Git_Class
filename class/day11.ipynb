# %% [markdown]
# # Day 11 — Modules, Packages, Virtual Environments & Conflict Prevention
#
# ## Learning Objectives
# - Build custom modules and packages.
# - Use `if __name__ == '__main__':` guards.
# - Manage isolated Virtual Environments (`.venv`) and `requirements.txt`.

# %% [markdown]
# ## 1. Module Self-Test Guard

# %%
# Module Code Example
def add(a, b): return a + b
def multiply(a, b): return a * b

if __name__ == "__main__":
    assert add(2, 3) == 5
    print("Module self-test passed successfully!")

# %% [markdown]
# ## 2. Virtual Environment Commands
# ```bash
# python -m venv .venv
# pip install requests
# pip freeze > requirements.txt
# ```
