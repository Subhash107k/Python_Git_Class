# %% [markdown]
# # Day 19 — Portfolio Project Architecture & Packaging
#
# ## Learning Objectives
# - Architect multi-module Python applications under `src/`.
# - Configure `setup.py` and `requirements.txt`.
# - Scaffold Capstone Portfolio Project.

# %% [markdown]
# ## 1. Package Configuration (`setup.py`)

# %%
# setup.py Scaffolding Example
# setuptools configuration for PAAMS CLI Application

# %% [markdown]
# ## 2. Git Commands
# ```bash
# git switch -c feature/portfolio-setup
# git add .
# git commit -m "chore: scaffold multi-module portfolio architecture"
# ```
